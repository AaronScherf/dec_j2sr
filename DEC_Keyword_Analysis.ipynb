# %% [markdown]
# # Topic Analysis on DEC Keywords

# %%
# Import Packages

# %%
# Import Data

dec_j2sr_data = pd.read_csv('dec_j2sr_data.csv')

# %%
dec_j2sr_data['Descriptors_Topical'] = dec_j2sr_data['Descriptors_Topical'].astype(str).str.replace(' ~\|~_©_~\|~', ",").str.lower()
dec_j2sr_data['Descriptors_Topical']
# Out:
# Unique_ID
# PD-AAB-495-E1                                                 management education, graduate education, limited data
# PD-AAP-604                          low cost housing, minimum shelter housing, housing, earthquakes, disaster relief
# PD-AAB-088-A1                                                                  road construction, roads, rural areas
# PD-AAA-880-D1      health surveys, demographic research, migration, samples, surveys, survey methodology, demography
# PD-AAT-461       condoms, sterilization (birth control), oral contraceptives, family planning occupations, medica...
#                                                                 ...
# PA-00S-RX6            food security, poverty reduction, nutrition improvement, malnutrition, agricultural production
# PA-00S-RV5       agricultural technology, crops, female empowerment, food production, households, irrigating, mai...
# PA-00S-RSS       tuberculosis, empowerment, community mobilization, disease prevention and control, health outcom...
# PA-00S-RRZ       communes, communities, disease prevention and control, health care costs, households, sports, us...
# PA-00S-RRS       tuberculosis, empowerment, community mobilization, disease prevention and control, health outcom...
# Name: Descriptors_Topical, Length: 12411, dtype: object

# %%
topic_dummies = dec_j2sr_data['Descriptors_Topical'].str.get_dummies(sep=',')
print(topic_dummies.shape)
topic_dummies.head()
# Out:
# (12411, 4327)
#                 ability   abortion   absorptive capacity   abstracting  \
# Unique_ID
# PD-AAB-495-E1         0          0                     0             0
# PD-AAP-604            0          0                     0             0
# PD-AAB-088-A1         0          0                     0             0
# PD-AAA-880-D1         0          0                     0             0
# PD-AAT-461            0          0                     0             0
#
#                 abstracts   acacia albida trees   academic standards  \
# Unique_ID
# PD-AAB-495-E1           0                     0                    0
# PD-AAP-604              0                     0                    0
# PD-AAB-088-A1           0                     0                    0
# PD-AAA-880-D1           0                     0                    0
# PD-AAT-461              0                     0                    0
#
#                 accelerated education   access roads   access to credit  ...  \
# Unique_ID                                                                ...
# PD-AAB-495-E1                       0              0                  0  ...
# PD-AAP-604                          0              0                  0  ...
# PD-AAB-088-A1                       0              0                  0  ...
# PD-AAA-880-D1                       0              0                  0  ...
# PD-AAT-461                          0              0                  0  ...
#
#                wheat  wholesale marketing  wildlife resources  windmills  \
# Unique_ID
# PD-AAB-495-E1      0                    0                   0          0
# PD-AAP-604         0                    0                   0          0
# PD-AAB-088-A1      0                    0                   0          0
# PD-AAA-880-D1      0                    0                   0          0
# PD-AAT-461         0                    0                   0          0
#
#                winter wheat  women  women in development  \
# Unique_ID
# PD-AAB-495-E1             0      0                     0
# PD-AAP-604                0      0                     0
# PD-AAB-088-A1             0      0                     0
# PD-AAA-880-D1             0      0                     0
# PD-AAT-461                0      0                     0
#
#                women's political leadership  women's rights  youth
# Unique_ID
# PD-AAB-495-E1                             0               0      0
# PD-AAP-604                                0               0      0
# PD-AAB-088-A1                             0               0      0
# PD-AAA-880-D1                             0               0      0
# PD-AAT-461                                0               0      0
#
# [5 rows x 4327 columns]

# %%
word_counts = topic_dummies.apply(pd.Series.value_counts)
word_counts
# Out:
#     ability   abortion   absorptive capacity   abstracting   abstracts  \
# 0     12410      12403                 12409         12410       12410
# 1         1          8                     2             1           1
#
#     acacia albida trees   academic standards   accelerated education  \
# 0                 12410                12408                   12409
# 1                     1                    3                       2
#
#     access roads   access to credit  ...  wheat  wholesale marketing  \
# 0          12378              12382  ...  12408                12410
# 1             33                 29  ...      3                    1
#
#    wildlife resources  windmills  winter wheat  women  women in development  \
# 0               12408      12409         12410  12404                 12310
# 1                   3          2             1      7                   101
#
#    women's political leadership  women's rights  youth
# 0                         12410           12408  12370
# 1                             1               3     41
#
# [2 rows x 4327 columns]

# %%
top_words = word_counts.iloc[1,].sort_values(ascending=False)
top_words = top_words[top_words > 20]
top_words.to_csv("top_words.csv")
top_words.shape
# Out:
# (879,)

# %%
topic_sample = topic_dummies.loc[:,top_words.index.values]
topic_sample = topic_sample.sample(n=5000)
topic_sample = topic_sample.replace(0, np.nan)
topic_sample = topic_sample.dropna(how='all', axis=0)
topic_sample = topic_sample.dropna(how='all', axis=1)
topic_sample = topic_sample.replace(np.nan, 0)

# %%
print(topic_sample.shape)
topic_sample
# Out:
# (4901, 879)
#              institution building   private voluntary organizations  \
# Unique_ID
# PD-AAT-253                    0.0                               0.0
# PD-ABX-772                    0.0                               0.0
# PD-ABN-012                    0.0                               0.0
# PD-ACL-685                    0.0                               0.0
# PD-AAS-195                    0.0                               0.0
# ...                           ...                               ...
# PD-ABC-558                    0.0                               0.0
# PA-00T-NQ8                    0.0                               0.0
# PN-AAB-684                    0.0                               0.0
# PD-ABN-209                    1.0                               0.0
# PD-ABP-863                    1.0                               0.0
#
#              disease prevention and control   rural areas   governance  \
# Unique_ID
# PD-AAT-253                              0.0           0.0          0.0
# PD-ABX-772                              0.0           0.0          0.0
# PD-ABN-012                              0.0           0.0          0.0
# PD-ACL-685                              0.0           0.0          0.0
# PD-AAS-195                              0.0           0.0          0.0
# ...                                     ...           ...          ...
# PD-ABC-558                              0.0           0.0          0.0
# PA-00T-NQ8                              0.0           0.0          0.0
# PN-AAB-684                              0.0           0.0          0.0
# PD-ABN-209                              0.0           0.0          0.0
# PD-ABP-863                              0.0           0.0          0.0
#
#              beneficiary interviews   community participation  \
# Unique_ID
# PD-AAT-253                      0.0                       0.0
# PD-ABX-772                      0.0                       0.0
# PD-ABN-012                      0.0                       0.0
# PD-ACL-685                      0.0                       0.0
# PD-AAS-195                      1.0                       0.0
# ...                             ...                       ...
# PD-ABC-558                      0.0                       0.0
# PA-00T-NQ8                      0.0                       0.0
# PN-AAB-684                      0.0                       0.0
# PD-ABN-209                      0.0                       0.0
# PD-ABP-863                      0.0                       0.0
#
#              beneficiary count  child survival activities  \
# Unique_ID
# PD-AAT-253                 0.0                        0.0
# PD-ABX-772                 0.0                        0.0
# PD-ABN-012                 0.0                        0.0
# PD-ACL-685                 0.0                        0.0
# PD-AAS-195                 0.0                        0.0
# ...                        ...                        ...
# PD-ABC-558                 0.0                        1.0
# PA-00T-NQ8                 0.0                        0.0
# PN-AAB-684                 0.0                        0.0
# PD-ABN-209                 0.0                        0.0
# PD-ABP-863                 0.0                        1.0
#
#              management training  ...   environmental research   crops  \
# Unique_ID                         ...
# PD-AAT-253                   0.0  ...                      0.0     0.0
# PD-ABX-772                   0.0  ...                      0.0     0.0
# PD-ABN-012                   0.0  ...                      0.0     0.0
# PD-ACL-685                   0.0  ...                      0.0     0.0
# PD-AAS-195                   0.0  ...                      0.0     0.0
# ...                          ...  ...                      ...     ...
# PD-ABC-558                   0.0  ...                      0.0     0.0
# PA-00T-NQ8                   0.0  ...                      0.0     0.0
# PN-AAB-684                   0.0  ...                      0.0     0.0
# PD-ABN-209                   0.0  ...                      0.0     0.0
# PD-ABP-863                   0.0  ...                      0.0     0.0
#
#             food for peace title iii   expenditures   health outcomes  \
# Unique_ID
# PD-AAT-253                       0.0            0.0               0.0
# PD-ABX-772                       0.0            0.0               0.0
# PD-ABN-012                       0.0            0.0               0.0
# PD-ACL-685                       0.0            0.0               0.0
# PD-AAS-195                       0.0            0.0               0.0
# ...                              ...            ...               ...
# PD-ABC-558                       0.0            0.0               0.0
# PA-00T-NQ8                       0.0            0.0               0.0
# PN-AAB-684                       0.0            0.0               0.0
# PD-ABN-209                       0.0            0.0               0.0
# PD-ABP-863                       0.0            0.0               0.0
#
#              structural adjustment  commodity import programs  \
# Unique_ID
# PD-AAT-253                     0.0                        0.0
# PD-ABX-772                     0.0                        0.0
# PD-ABN-012                     0.0                        0.0
# PD-ACL-685                     0.0                        0.0
# PD-AAS-195                     0.0                        0.0
# ...                            ...                        ...
# PD-ABC-558                     0.0                        0.0
# PA-00T-NQ8                     0.0                        0.0
# PN-AAB-684                     0.0                        0.0
# PD-ABN-209                     0.0                        0.0
# PD-ABP-863                     0.0                        0.0
#
#              procedural development   capital markets   fertility
# Unique_ID
# PD-AAT-253                      0.0               0.0         0.0
# PD-ABX-772                      0.0               0.0         0.0
# PD-ABN-012                      0.0               0.0         0.0
# PD-ACL-685                      0.0               0.0         0.0
# PD-AAS-195                      0.0               0.0         0.0
# ...                             ...               ...         ...
# PD-ABC-558                      0.0               0.0         0.0
# PA-00T-NQ8                      0.0               0.0         0.0
# PN-AAB-684                      0.0               0.0         0.0
# PD-ABN-209                      0.0               0.0         0.0
# PD-ABP-863                      0.0               0.0         0.0
#
# [4901 rows x 879 columns]

# %% [markdown]
# ### Find Clusters of Categories with K-Modes Unsupervised Learning

# %%
# https://medium.com/@davidmasse8/unsupervised-learning-for-categorical-data-dd7e497033ae
# https://www.kaggle.com/ashydv/bank-customer-clustering-k-modes-clustering
# https://pypi.org/project/kmodes/

from kmodes.kmodes import KModes

# define the k-modes model
km = KModes(n_clusters=20, init='Huang', n_init=10, verbose=1)

# fit the clusters to the skills dataframe
clusters = km.fit_predict(topic_sample)

# get an array of cluster modes
kmodes = km.cluster_centroids_
shape = kmodes.shape

# For each cluster mode (a vector of "1" and "0")
# find and print the column headings where "1" appears.
# If no "1" appears, assign to "no-skills" cluster.

for i in range(shape[0]):
    if sum(kmodes[i,:]) == 0:
        print("\ncluster " + str(i) + ": ")
        print("no-topic cluster")
    else:
        print("\ncluster " + str(i) + ": ")
        cent = kmodes[i,:]
        for j in topic_sample.columns[np.nonzero(cent)]:
            print(j)

# %%
#topic_sample.loc[:,'clusters'] = clusters

# %%
#topic_sample.to_csv("topic_sample.csv")
